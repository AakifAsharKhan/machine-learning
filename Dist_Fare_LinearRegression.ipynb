# %% [markdown]
# <a href="https://colab.research.google.com/github/AakifAsharKhan/machine-learning/blob/main/Dist_Fare_LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

files.upload()
# Out:
#      <input type="file" id="files-feaa463f-fc50-4b74-b83a-bd23bbdba802" name="files[]" multiple disabled />
#      <output id="result-feaa463f-fc50-4b74-b83a-bd23bbdba802">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Dist_Fare.xlsx to Dist_Fare (1).xlsx
# ...

# %%
import pandas as pd

df = pd.read_excel('Dist_Fare.xlsx')

# %%
df.head()
# Out:
#    Dist  Fare
# 0     2    20
# 1     3    27
# 2     4    30
# 3     5    44
# 4     6    47

# %%
df.shape
# Out:
# (9, 2)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
y = df['Fare']

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
df.shape
# Out:
# (9, 2)

# %%
df.drop(['Fare'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (9, 1)

# %%
df.values
# Out:
# array([[ 2],
#        [ 3],
#        [ 4],
#        [ 5],
#        [ 6],
#        [ 7],
#        [ 8],
#        [ 9],
#        [10]])

# %%
x= df.values

# %%
x
# Out:
# array([[ 2],
#        [ 3],
#        [ 4],
#        [ 5],
#        [ 6],
#        [ 7],
#        [ 8],
#        [ 9],
#        [10]])

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.intercept_
# Out:
# -0.022222222222247012

# %%
lr.coef_
# Out:
# array([8.46666667])

# %%
lr.predict([[20]])
# Out:
# array([169.31111111])

# %%
lr.predict([[15]])
# Out:
# array([126.97777778])
