# %% [markdown]
# <a href="https://colab.research.google.com/github/AakifAsharKhan/machine-learning/blob/main/Multiple_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-274fff7e-5e63-4971-a6d9-67d845cf457a" name="files[]" multiple disabled />
#      <output id="result-274fff7e-5e63-4971-a6d9-67d845cf457a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving multiple-regression.xlsx to multiple-regression.xlsx
# ...

# %%
import pandas as pd

# %%
df = pd.read_excel('multiple-regression.xlsx')

# %%
df.head()
# Out:
#          X1        X2        X3          Y
# 0  2.231624  0.323345  1.134460   5.783532
# 1  1.492844  4.328616  6.126763  43.531591
# 2  1.418358  7.401440  8.384375  60.420338
# 3  0.754847  7.417910  1.193279  34.488660
# 4  1.855527  5.944293  9.074455  56.047605

# %%
y = df['Y']

# %%
df.drop(['Y'], axis=1, inplace=True)

# %%
x = df.values

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.predict([])
